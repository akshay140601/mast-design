# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import StackingRegressor
import xgboost as xgb
from sklearn.metrics import mean_squared_error
from sklearn import linear_model

# %%
data = pd.read_excel("C:\\Users\\fl9768\\Desktop\\Data for ML\\Horizontal tramming\\Horizontal_tramming_train.xlsx")

# %%
data.head()
# Out:
#    Mast name        Load case    Weight  Sectionmodulus  Overhang  \
# 0  DR410i SP  1.5G Self weight  33736.5        3.901175   367.375
# 1  DR410i SP  1.6G Self weight  35985.6        3.901175   367.375
# 2  DR410i SP  1.7G Self weight  38234.7        3.901175   367.375
# 3  DR410i SP  1.3G Self weight  29238.3        3.901175   367.375
# 4  DR410i SP  1.2G Self weight  26989.2        3.901175   367.375
#
#    Stressvalue  Deflection (in)
# 0      25021.0           2.7412
# 1      26756.0           2.9239
# 2      28491.0           3.1066
# 3      21552.0           2.3757
# 4      19817.0           2.1929

# %%
data = data.drop('Mast name', axis = 'columns')
data = data.drop('Load case ', axis = 'columns')
#data = data.drop('Deflection (in)', axis = 'columns')
data.head()
# Out:
#     Weight  Sectionmodulus  Overhang  Stressvalue  Deflection (in)
# 0  33736.5        3.901175   367.375      25021.0           2.7412
# 1  35985.6        3.901175   367.375      26756.0           2.9239
# 2  38234.7        3.901175   367.375      28491.0           3.1066
# 3  29238.3        3.901175   367.375      21552.0           2.3757
# 4  26989.2        3.901175   367.375      19817.0           2.1929

# %%
import smogn

# %%
rg_mtrx = [
 #   [24000,1,0],
    [30000,1,0],
 #   [20000,1,0],
#   [15000,1,0],
#     [20000,1,0],
 #    [21000,1,0],
#     [21500,1,0],
#     [22000,1,0],
#     [22500,1,0],
#     [23000,1,0],
#     [23500,1,0],
#     [24000,1,0],
#     [24500,1,0],
#     [25000,1,0],
 #    [25500,1,0],
#     [26000,1,0],
#     [26500,1,0],
#     [27000,1,0],
#     [27500,1,0],
    [10000,0,0],
    [36000,1,0],
#     [37000,0,0]
]

# rg_mtrx = [

#     [8000, 1, 0],  ## over-sample ("minority")
#     [8500, 1, 0],
#     [9000, 1, 0],
#     [9500, 1, 0],
# #     [10000, 1, 0],
# #     [10500, 1, 0],
# #     [11000, 1, 0],
# #     [11500, 1, 0],
# #     [12000, 1, 0],
# #     [12500, 1, 0],
# #     [13000, 1, 0],
# #     [13500, 1, 0],
# #     [14000, 1, 0],
# #     [14500, 1, 0],
# #     [15000, 1, 0],
# #     [15500, 1, 0],
# #     [16000, 1, 0],
# #     [16500, 1, 0],
# #     [17000, 1, 0],
# #     [17500, 1, 0],
# #     [18000, 1, 0],
# #     [18500, 1, 0],
# #     [19000, 1, 0],
# #     [19500, 1, 0],
# #     [20000, 1, 0],
# #     [20500, 1, 0],
# #     [21000, 1, 0],
# #     [11000, 1, 0],
# #     [12500, 1, 0],
# #     [18000, 1, 0],
# #     [19000, 1, 0],
# #     [20000, 1, 0],
#     [28000, 0, 0]
# ]

# %%
data_smogn = smogn.smoter(data = data, y = "Stressvalue", rel_method = 'manual', rel_ctrl_pts_rg = rg_mtrx, samp_method = 'extreme')
# Out:
# dist_matrix: 100%|#####################################################################| 4/4 [00:00<00:00, 2005.40it/s]
# synth_matrix: 100%|#####################################################################| 4/4 [00:00<00:00, 668.92it/s]
# dist_matrix: 100%|#####################################################################| 7/7 [00:00<00:00, 1170.52it/s]
# r_index: 100%|#########################################################################| 2/2 [00:00<00:00, 1004.86it/s]

# %%
data_smogn
# Out:
#           Weight  Sectionmodulus    Overhang   Stressvalue  Deflection (in)
# 0   33736.500000        3.901175  367.375000  25021.000000         2.741200
# 2   38234.700000        3.901175  367.375000  28491.000000         3.106600
# 4   26989.200000        3.901175  367.375000  19817.000000         2.192900
# 5   32568.000000        3.901175  209.375000  12391.000000         0.490000
# 6   34603.500000        3.901175  209.375000  13166.000000         0.520000
# 7   28497.000000        3.901175  209.375000  10842.000000         0.430000
# 8   26461.500000        3.901175  209.375000  10068.000000         0.400000
# 9   24426.000000        3.901175  209.375000   9293.500000         0.370000
# 10  35533.500000        4.882331  450.375000  25465.000000         2.803000
# 11  37902.400000        4.882331  450.375000  27163.000000         2.990000
# 12  40271.300000        4.882331  450.375000  28861.000000         3.177000
# 13  33164.600000        4.882331  450.375000  23768.000000         2.616000
# 14  30795.700000        4.882331  450.375000  22070.000000         2.429000
# 15  48853.500000        4.319538  430.000000  31898.000000         3.258000
# 16  55367.300000        4.319538  430.000000  36151.000000         3.692000
# 17  45596.600000        4.319538  430.000000  29771.000000         3.041000
# 18  42339.700000        4.319538  430.000000  27645.000000         2.824000
# 19  39082.800000        4.319538  430.000000  25518.000000         2.606000
# 20  54870.000000        4.657866  178.205000  10176.000000         0.297900
# 21  58528.000000        4.657866  178.205000  10879.000000         0.317900
# 22  51212.000000        4.657866  178.205000   9633.000000         0.278200
# 23  47554.000000        4.657866  178.205000   8859.400000         0.258300
# 24  43896.000000        4.657866  178.205000   8257.000000         0.238400
# 25  49437.000000        4.319538  426.000000  30731.000000         2.825000
# 26  52732.800000        4.319538  426.000000  32779.000000         3.013300
# 27  56028.600000        4.319538  426.000000  34828.000000         3.201700
# 29  39549.600000        4.319538  426.000000  24585.000000         2.260000
# 0   26652.088935        3.901175  209.375000  10440.672152         0.402809
# 1   58468.775562        4.655248  178.208946  11018.107233         0.330357
# 0   44090.685169        4.647222  178.272326   8245.339296         0.239915
# 1   43802.447447        4.660139  177.681033   8267.151688         0.238399
# 2   44087.081441        4.647304  177.887158   8264.416314         0.238143
# 3   47120.329176        4.656920  177.873486   8863.926653         0.256630
# 4   47771.044342        4.647855  178.620588   8854.645905         0.257849
# 5   47598.617952        4.659895  178.095141   8865.919842         0.258926
# 6   24139.460478        3.907982  209.479172   9289.446282         0.370655
# 7   24271.136193        3.904760  209.423822   9307.247626         0.372828
# 8   24333.395116        3.901343  209.749243   9302.789969         0.370993
# 9   51071.998624        4.659972  178.005377   9641.625255         0.278089
# 10  51487.366562        4.652689  178.208749   9630.121192         0.279396
# 11  51552.767391        4.656795  178.416293   9639.690361         0.277429

# %%
data.shape
# Out:
# (30, 5)

# %%
data_smogn.shape
# Out:
# (41, 5)

# %%
frames = [data, data_smogn]
df = pd.concat(frames)
df
# Out:
#           Weight  Sectionmodulus    Overhang   Stressvalue  Deflection (in)
# 0   33736.500000        3.901175  367.375000  25021.000000         2.741200
# 1   35985.600000        3.901175  367.375000  26756.000000         2.923900
# 2   38234.700000        3.901175  367.375000  28491.000000         3.106600
# 3   29238.300000        3.901175  367.375000  21552.000000         2.375700
# 4   26989.200000        3.901175  367.375000  19817.000000         2.192900
# ..           ...             ...         ...           ...              ...
# 7   24271.136193        3.904760  209.423822   9307.247626         0.372828
# 8   24333.395116        3.901343  209.749243   9302.789969         0.370993
# 9   51071.998624        4.659972  178.005377   9641.625255         0.278089
# 10  51487.366562        4.652689  178.208749   9630.121192         0.279396
# 11  51552.767391        4.656795  178.416293   9639.690361         0.277429
#
# [71 rows x 5 columns]

# %%
X_train = data[["Weight", "Sectionmodulus", "Overhang"]]
y_train = data[["Deflection (in)"]]
test_data = pd.read_excel("C:\\Users\\fl9768\\Desktop\\Data for ML\\Horizontal tramming\\Horizontal_tramming_test.xlsx")
X_test = test_data[["Weight", "Sectionmodulus", "Overhang"]]
y_test = test_data[["Deflection (in)"]]

# %%
base_learners = [('xgb1', xgb.XGBRegressor(max_depth = 2, n_estimators = 1000, learning_rate = 0.05, 
                                           gamma = 0.9, random_state = 100)),
                ('xgb2', xgb.XGBRegressor(max_depth = 6, n_estimators = 1500, learning_rate = 0.15, 
                                           gamma = 0.9, random_state = 100)),
                ('rf1', RandomForestRegressor(max_depth = 3, n_estimators = 175, random_state = 100)),
                ('rf2', RandomForestRegressor(max_depth = 10, n_estimators = 175, random_state = 100)),
                ('lr', linear_model.LinearRegression())]

# %%
final_reg = StackingRegressor(estimators = base_learners, final_estimator = linear_model.LinearRegression())
final_reg.fit(X_train, y_train.values.ravel())
y_pred_final_reg = final_reg.predict(X_test)
print('RMSE: {}'.format(np.sqrt(mean_squared_error(y_test, y_pred_final_reg))))
# Out:
# RMSE: 0.2619029508470733

# %%
y_test['Predicted value stack'] = y_pred_final_reg
y_test['Difference'] = abs(y_test['Deflection (in)'] - y_test['Predicted value stack'])
y_test
# Out:
# C:\Users\fl9768\AppData\Local\Temp\ipykernel_2344\4006688391.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_test['Predicted value stack'] = y_pred_final_reg
# C:\Users\fl9768\AppData\Local\Temp\ipykernel_2344\4006688391.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_test['Difference'] = abs(y_test['Deflection (in)'] - y_test['Predicted value stack'])
#    Deflection (in)  Predicted value stack  Difference
# 0           2.5584               2.644676    0.086276
# 1           0.4600               0.333326    0.126674
# 2           2.2420               2.725355    0.483355
# 3           3.4750               3.142740    0.332260
# 4           0.3378               0.288699    0.049101
# 5           2.4483               2.652333    0.204033

# %%
import pickle
pickle.dump(final_reg, open('hor_tram_stack_deflection.pkl', 'wb'))

# %%
hor_tram_prediction = pickle.load(open('hor_tram_stack_deflection.pkl', 'rb'))
hor_tram_prediction.predict(X_test)
# Out:
# array([2.64467556, 0.33332588, 2.72535471, 3.1427398 , 0.28869946,
#        2.65233346])
