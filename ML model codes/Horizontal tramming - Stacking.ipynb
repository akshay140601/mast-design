# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import StackingRegressor
import xgboost as xgb
from sklearn.metrics import mean_squared_error
from sklearn import linear_model

# %%
data = pd.read_excel("C:\\Users\\fl9768\\Desktop\\Data for ML\\Horizontal tramming\\Horizontal_tramming_train.xlsx")

# %%
data.head()
# Out:
#    Mast name        Load case    Weight  Sectionmodulus  Overhang  \
# 0  DR410i SP  1.5G Self weight  33736.5        3.901175   367.375
# 1  DR410i SP  1.6G Self weight  35985.6        3.901175   367.375
# 2  DR410i SP  1.7G Self weight  38234.7        3.901175   367.375
# 3  DR410i SP  1.3G Self weight  29238.3        3.901175   367.375
# 4  DR410i SP  1.2G Self weight  26989.2        3.901175   367.375
#
#    Stressvalue  Deflection (in)
# 0      25021.0           2.7412
# 1      26756.0           2.9239
# 2      28491.0           3.1066
# 3      21552.0           2.3757
# 4      19817.0           2.1929

# %%
data = data.drop('Mast name', axis = 'columns')
data = data.drop('Load case ', axis = 'columns')
data = data.drop('Deflection (in)', axis = 'columns')
data.head()
# Out:
#     Weight  Sectionmodulus  Overhang  Stressvalue
# 0  33736.5        3.901175   367.375      25021.0
# 1  35985.6        3.901175   367.375      26756.0
# 2  38234.7        3.901175   367.375      28491.0
# 3  29238.3        3.901175   367.375      21552.0
# 4  26989.2        3.901175   367.375      19817.0

# %%
import smogn

# %%
rg_mtrx = [
 #   [24000,1,0],
    [30000,1,0],
 #   [20000,1,0],
#   [15000,1,0],
#     [20000,1,0],
 #    [21000,1,0],
#     [21500,1,0],
#     [22000,1,0],
#     [22500,1,0],
#     [23000,1,0],
#     [23500,1,0],
#     [24000,1,0],
#     [24500,1,0],
#     [25000,1,0],
 #    [25500,1,0],
#     [26000,1,0],
#     [26500,1,0],
#     [27000,1,0],
#     [27500,1,0],
    [10000,0,0],
    [36000,1,0],
#     [37000,0,0]
]

# rg_mtrx = [

#     [8000, 1, 0],  ## over-sample ("minority")
#     [8500, 1, 0],
#     [9000, 1, 0],
#     [9500, 1, 0],
# #     [10000, 1, 0],
# #     [10500, 1, 0],
# #     [11000, 1, 0],
# #     [11500, 1, 0],
# #     [12000, 1, 0],
# #     [12500, 1, 0],
# #     [13000, 1, 0],
# #     [13500, 1, 0],
# #     [14000, 1, 0],
# #     [14500, 1, 0],
# #     [15000, 1, 0],
# #     [15500, 1, 0],
# #     [16000, 1, 0],
# #     [16500, 1, 0],
# #     [17000, 1, 0],
# #     [17500, 1, 0],
# #     [18000, 1, 0],
# #     [18500, 1, 0],
# #     [19000, 1, 0],
# #     [19500, 1, 0],
# #     [20000, 1, 0],
# #     [20500, 1, 0],
# #     [21000, 1, 0],
# #     [11000, 1, 0],
# #     [12500, 1, 0],
# #     [18000, 1, 0],
# #     [19000, 1, 0],
# #     [20000, 1, 0],
#     [28000, 0, 0]
# ]

# %%
data_smogn = smogn.smoter(data = data, y = "Stressvalue", rel_method = 'manual', rel_ctrl_pts_rg = rg_mtrx, samp_method = 'extreme')
# Out:
# dist_matrix: 100%|#####################################################################| 4/4 [00:00<00:00, 3994.58it/s]
# synth_matrix: 100%|#####################################################################| 4/4 [00:00<00:00, 802.81it/s]
# dist_matrix: 100%|#####################################################################| 7/7 [00:00<00:00, 1405.60it/s]
# r_index: 100%|#########################################################################| 2/2 [00:00<00:00, 2008.77it/s]

# %%
data_smogn
# Out:
#           Weight  Sectionmodulus    Overhang   Stressvalue
# 0   33736.500000        3.901175  367.375000  25021.000000
# 1   35985.600000        3.901175  367.375000  26756.000000
# 2   38234.700000        3.901175  367.375000  28491.000000
# 3   29238.300000        3.901175  367.375000  21552.000000
# 4   26989.200000        3.901175  367.375000  19817.000000
# 5   32568.000000        3.901175  209.375000  12391.000000
# 6   34603.500000        3.901175  209.375000  13166.000000
# 7   28497.000000        3.901175  209.375000  10842.000000
# 8   26461.500000        3.901175  209.375000  10068.000000
# 9   24426.000000        3.901175  209.375000   9293.500000
# 10  35533.500000        4.882331  450.375000  25465.000000
# 11  37902.400000        4.882331  450.375000  27163.000000
# 12  40271.300000        4.882331  450.375000  28861.000000
# 13  33164.600000        4.882331  450.375000  23768.000000
# 14  30795.700000        4.882331  450.375000  22070.000000
# 16  55367.300000        4.319538  430.000000  36151.000000
# 17  45596.600000        4.319538  430.000000  29771.000000
# 19  39082.800000        4.319538  430.000000  25518.000000
# 20  54870.000000        4.657866  178.205000  10176.000000
# 21  58528.000000        4.657866  178.205000  10879.000000
# 22  51212.000000        4.657866  178.205000   9633.000000
# 23  47554.000000        4.657866  178.205000   8859.400000
# 24  43896.000000        4.657866  178.205000   8257.000000
# 25  49437.000000        4.319538  426.000000  30731.000000
# 26  52732.800000        4.319538  426.000000  32779.000000
# 27  56028.600000        4.319538  426.000000  34828.000000
# 28  46141.200000        4.319538  426.000000  28682.000000
# 0   32620.461986        3.900763  207.203627  12374.976855
# 1   26971.742538        3.893328  367.836937  19747.708080
# 0   43602.841732        4.656938  178.740067   8262.026638
# 1   44124.113355        4.653692  178.146238   8238.553221
# 2   43936.113875        4.661215  178.232737   8266.108819
# 3   47426.771972        4.662425  178.213881   8875.542755
# 4   47684.109665        4.658198  178.301080   8863.420423
# 5   47788.371113        4.655323  178.000470   8851.674366
# 6   24392.025968        3.900554  208.882943   9294.650914
# 7   24229.707051        3.896432  209.360873   9281.738849
# 8   24508.153769        3.893437  209.529062   9300.184243
# 9   51526.167630        4.665916  178.410335   9628.243851
# 10  51138.808603        4.655969  177.772326   9649.455168
# 11  51101.425956        4.668971  178.758458   9631.430555

# %%
data.shape
# Out:
# (30, 4)

# %%
data_smogn.shape
# Out:
# (41, 4)

# %%
frames = [data, data_smogn]
df = pd.concat(frames)
df
# Out:
#           Weight  Sectionmodulus    Overhang   Stressvalue
# 0   33736.500000        3.901175  367.375000  25021.000000
# 1   35985.600000        3.901175  367.375000  26756.000000
# 2   38234.700000        3.901175  367.375000  28491.000000
# 3   29238.300000        3.901175  367.375000  21552.000000
# 4   26989.200000        3.901175  367.375000  19817.000000
# ..           ...             ...         ...           ...
# 7   24229.707051        3.896432  209.360873   9281.738849
# 8   24508.153769        3.893437  209.529062   9300.184243
# 9   51526.167630        4.665916  178.410335   9628.243851
# 10  51138.808603        4.655969  177.772326   9649.455168
# 11  51101.425956        4.668971  178.758458   9631.430555
#
# [71 rows x 4 columns]

# %%
X_train = data[["Weight", "Sectionmodulus", "Overhang"]]
y_train = data[["Stressvalue"]]
test_data = pd.read_excel("C:\\Users\\fl9768\\Desktop\\Data for ML\\Horizontal tramming\\Horizontal_tramming_test.xlsx")
X_test = test_data[["Weight", "Sectionmodulus", "Overhang"]]
y_test = test_data[["Stressvalue"]]

# %%
base_learners = [('xgb1', xgb.XGBRegressor(max_depth = 2, n_estimators = 1000, learning_rate = 0.05, 
                                           gamma = 0.9, random_state = 100)),
                ('xgb2', xgb.XGBRegressor(max_depth = 6, n_estimators = 1500, learning_rate = 0.15, 
                                           gamma = 0.9, random_state = 100)),
                ('rf1', RandomForestRegressor(max_depth = 3, n_estimators = 175, random_state = 100)),
                ('rf2', RandomForestRegressor(max_depth = 10, n_estimators = 175, random_state = 100)),
                ('lr', linear_model.LinearRegression())]

# %%
final_reg = StackingRegressor(estimators = base_learners, final_estimator = linear_model.LinearRegression())
final_reg.fit(X_train, y_train.values.ravel())
y_pred_final_reg = final_reg.predict(X_test)
print('RMSE: {}'.format(np.sqrt(mean_squared_error(y_test, y_pred_final_reg))))
# Out:
# RMSE: 591.2236743524675

# %%
y_test['Predicted value stack'] = y_pred_final_reg
y_test['Difference'] = abs(y_test['Stressvalue'] - y_test['Predicted value stack'])
y_test
# Out:
# C:\Users\fl9768\AppData\Local\Temp\ipykernel_15704\339197596.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_test['Predicted value stack'] = y_pred_final_reg
# C:\Users\fl9768\AppData\Local\Temp\ipykernel_15704\339197596.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_test['Difference'] = abs(y_test['Stressvalue'] - y_test['Predicted value stack'])
#    Stressvalue  Predicted value stack   Difference
# 0        23287           22006.152646  1280.847354
# 1        11617           11091.947050   525.052950
# 2        20372           20274.025539    97.974461
# 3        34024           34009.503474    14.496526
# 4        11697           11527.388670   169.611330
# 5        26633           27010.418741   377.418741

# %%
import pickle
pickle.dump(final_reg, open('hor_tram_stack.pkl', 'wb'))

# %%
hor_tram_prediction = pickle.load(open('hor_tram_stack.pkl', 'rb'))
hor_tram_prediction.predict(X_test)
# Out:
# array([22006.15264563, 11091.94705003, 20274.02553883, 34009.50347404,
#        11527.38867035, 27010.41874061])
